# %%
import os
import pandas as pd
# %matplotlib inline

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Read your api key environment variable
from newsapi.newsapi_client import NewsApiClient

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=os.environ["news_api"])

# %%
# Fetch the Bitcoin news articles
bch= newsapi.get_everything(
    q="Bitcoin",
    language="en",
    page_size=100,
    sort_by="relevancy"
)


print(f"Total articles about Bitcoin: {bch['totalResults']}")

# Show sample article
bch["articles"][0]
# Out:
# Total articles about Bitcoin: 3331
# {'source': {'id': 'wired', 'name': 'Wired'},
#  'author': 'Brian Barrett',
#  'title': "The 'Robo Revenge' App Makes It Easy to Sue Robocallers",
#  'description': "Mac malware, a Bitcoin mixer, and more of the week's top security news.",
#  'url': 'https://www.wired.com/story/robo-revenge-apple-malware-security-news/',
#  'urlToImage': 'https://media.wired.com/photos/5e471046e7120600088b2022/191:100/w_1280,c_limit/Security_robbocalls-84289419.jpg',
#  'publishedAt': '2020-02-15T14:00:00Z',
#  'content': "Just when you thought the catastrophic Equifax breach was entirely in the rearview, the Department of Justice this week charged four Chinese military hackers with the theft. That's 147.9 million people's Social Security numbers and other personal information … [+4002 chars]"}

# %%
# Fetch the Ethereum news articles
eth = newsapi.get_everything(
    q="Ethereum",
    language='en',
    page_size=100,
    sort_by='relevancy'
)

print(f"Total articles about Ethereum: {eth['totalResults']}")

eth['articles'][0]
# Out:
# Total articles about Ethereum: 832
# {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#  'author': 'Greg Kumparak',
#  'title': 'Horizon raises another $5M to put virtual items on the blockchain and launch its first game',
#  'description': 'If a player picks up an item in an online video game, who owns that item? The player, or the company that made the game? In most cases, the answer is probably closer to the latter. The item may be in the player’s digital inventory – but the company can take i…',
#  'url': 'http://techcrunch.com/2020/03/06/horizon-raises-another-5m-to-put-virtual-items-on-the-blockchain/',
#  'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/03/skyweaver.png?w=756',
#  'publishedAt': '2020-03-06T17:01:15Z',
# ...

# %%
# Create the Bitcoin sentiment scores DataFrame

bitsent = []

for article in bch['articles']:
    try:
        sentiment = analyzer.polarity_scores(article['content'])
        
        bitsent.append({
            'text': article['content'],
            'compound': sentiment['compound'],
            'positive': sentiment['pos'],
            'negative': sentiment['neg'],
            'neutral': sentiment['neu']
        })
    except AttributeError:
        pass
    
bcoin_df = pd.DataFrame(bitsent)

cols =['compound','negative','neutral','positive','text']
bcoin_df = bcoin_df[cols]

bcoin_df.head()
# Out:
#    compound  negative  neutral  positive  \
# 0    0.2023     0.107    0.769     0.124
# 1    0.0000     0.000    1.000     0.000
# 2    0.0000     0.000    1.000     0.000
# 3   -0.5106     0.168    0.730     0.103
# 4    0.1280     0.041    0.907     0.052
#
#                                                 text
# 0  Just when you thought the catastrophic Equifax...
# 1  After launching two cryptocurrency-oriented sm...
# 2  If youve been following cryptocurrency news fo...
# 3  Indias Supreme Court on Wednesday overturned c...
# 4  But its still unclear if you need to report th...

# %%
# Create the ethereum sentiment scores DataFrame

ethsent = []

for article in eth['articles']:
    try:
        sentiment = analyzer.polarity_scores(article['content'])
        
        ethsent.append({
            'compound': sentiment['compound'],
            'negative': sentiment['neg'],
            'positive': sentiment['pos'],
            'neutral': sentiment['neu'],
            'text':article['content']
        })
    
    except AttributeError:
        pass
        
eth_df = pd.DataFrame(ethsent)

eth_df.head()
# Out:
#    compound  negative  positive  neutral  \
# 0    0.0000     0.000     0.000    1.000
# 1    0.0000     0.000     0.000    1.000
# 2    0.3182     0.066     0.112    0.822
# 3    0.7184     0.000     0.130    0.870
# 4    0.4019     0.000     0.068    0.932
#
#                                                 text
# 0  If a player picks up an item in an online vide...
# 1  If youve been following cryptocurrency news fo...
# 2  When it comes to celebrities shilling shady in...
# 3  Skale Network is taking steps to help its cryp...
# 4  The South Korean National Assembly passed new ...

# %%
# Describe the Bitcoin Sentiment
bcoin_df.describe()
# Out:
#         compound   negative    neutral   positive
# count  92.000000  92.000000  92.000000  92.000000
# mean    0.142233   0.054609   0.859739   0.085717
# std     0.537689   0.070907   0.103352   0.086159
# min    -0.933700   0.000000   0.375000   0.000000
# 25%    -0.279800   0.000000   0.809250   0.039250
# 50%     0.273550   0.012500   0.875000   0.068000
# 75%     0.556575   0.093500   0.932000   0.121250
# max     0.906000   0.295000   1.000000   0.625000

# %%
# Describe the Ethereum Sentiment
eth_df.describe()
# Out:
#         compound   negative   positive    neutral
# count  96.000000  96.000000  96.000000  96.000000
# mean    0.261555   0.021812   0.068510   0.909677
# std     0.398533   0.038587   0.065432   0.072425
# min    -0.802000   0.000000   0.000000   0.682000
# 25%     0.000000   0.000000   0.000000   0.858000
# 50%     0.340000   0.000000   0.062000   0.928500
# 75%     0.599400   0.041000   0.121250   0.952750
# max     0.905900   0.177000   0.254000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin
#
# Q: Which coin had the highest compound score?
#
# A: etherum?
#
# Q. Which coin had the highest positive score?
#
# A: bitcoin..

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Expand the default stopwords list if necessary
lemmatizer = WordNetLemmatizer()

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Create a list of the words
    regex = re.compile('[^a-zA-Z ]')
    re_clean = regex.sub(' ',text)
    # Convert the words to lowercase
    words = word_tokenize(re_clean)
    # Remove the punctuation 
    sw = set(stopwords.words('english'))

    # Remove the stop words
   
    # Lemmatize Words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return output

# %%
# Create a new tokens column for bitcoin
bcoin_df['tokens'] = bcoin_df['text'].apply(lambda x: tokenizer(x))
bc_token
bcoin_df.head()
# Out:
#    compound  negative  neutral  positive  \
# 0    0.2023     0.107    0.769     0.124
# 1    0.0000     0.000    1.000     0.000
# 2    0.0000     0.000    1.000     0.000
# 3   -0.5106     0.168    0.730     0.103
# 4    0.1280     0.041    0.907     0.052
#
#                                                 text  \
# 0  Just when you thought the catastrophic Equifax...
# 1  After launching two cryptocurrency-oriented sm...
# 2  If youve been following cryptocurrency news fo...
# 3  Indias Supreme Court on Wednesday overturned c...
# 4  But its still unclear if you need to report th...
#
#                                               tokens
# 0  [thought, catastrophic, equifax, breach, wa, e...
# 1  [launching, two, cryptocurrency, oriented, sma...
# 2  [youve, following, cryptocurrency, news, past,...
# 3  [indias, supreme, court, wednesday, overturned...
# 4  [still, unclear, need, report, image, epic, ga...

# %%
# Create a new tokens column for ethereum
eth_df['tokens'] = eth_df['text'].apply(lambda x: tokenizer(x))
eth_df.head()
# Out:
#    compound  negative  positive  neutral  \
# 0    0.0000     0.000     0.000    1.000
# 1    0.0000     0.000     0.000    1.000
# 2    0.3182     0.066     0.112    0.822
# 3    0.7184     0.000     0.130    0.870
# 4    0.4019     0.000     0.068    0.932
#
#                                                 text  \
# 0  If a player picks up an item in an online vide...
# 1  If youve been following cryptocurrency news fo...
# 2  When it comes to celebrities shilling shady in...
# 3  Skale Network is taking steps to help its cryp...
# 4  The South Korean National Assembly passed new ...
#
#                                               tokens
# 0  [player, pick, item, online, video, game, owns...
# 1  [youve, following, cryptocurrency, news, past,...
# 2  [come, celebrity, shilling, shady, initial, co...
# 3  [skale, network, taking, step, help, cryptocur...
# 4  [south, korean, national, assembly, passed, ne...

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

lemmatizer = WordNetLemmatizer()

# %%
# Generate the Bitcoin N-grams where N=2
def process_text(doc):
    """Process' text with tokenizer."""
    
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub(' ', doc)
    words = word_tokenize(re_clean)
    sw = set(stopwords.words('english'))

    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return output

# %%
bc_joined = ' '.join(bcoin_df['text'])

# %%
processed_bc = process_text(bc_joined)
processed_bc
#processed_bc = bcoin_df['text'].apply(lambda x: process_text(x))

#from collections import Counter
word_counts_bc = Counter(processed_bc)

bigram_counts_bc = Counter(ngrams(processed_bc,n=2))

bigram_counts_bc
# Out:
# Counter({('thought', 'catastrophic'): 1,
#          ('catastrophic', 'equifax'): 1,
#          ('equifax', 'breach'): 1,
#          ('breach', 'wa'): 1,
#          ('wa', 'entirely'): 1,
#          ('entirely', 'rearview'): 1,
#          ('rearview', 'department'): 1,
#          ('department', 'justice'): 1,
#          ('justice', 'week'): 1,
#          ('week', 'charged'): 1,
#          ('charged', 'four'): 1,
#          ('four', 'chinese'): 1,
#          ('chinese', 'military'): 1,
#          ('military', 'hacker'): 1,
#          ('hacker', 'theft'): 1,
#          ('theft', 'million'): 1,
#          ('million', 'people'): 1,
#          ('people', 'social'): 1,
#          ('social', 'security'): 1,
#          ('security', 'number'): 1,
#          ('number', 'personal'): 1,
#          ('personal', 'information'): 1,
#          ('information', 'char'): 1,
#          ('char', 'launching'): 1,
#          ('launching', 'two'): 1,
#          ('two', 'cryptocurrency'): 1,
# ...

# %%
# Generate the Ethereum N-grams where N=2
eth_joined = ' '.join(eth_df['text'])

processed_eth = process_text(eth_joined)

word_counts_eth = Counter(processed_eth)

bigram_counts_eth = Counter(ngrams(processed_eth,n=2))

bigram_counts_eth

#???
#vectorizer = CountVectorizer(stop_words="english")
#X = vectorizer.fit_transform([doc_text])
#words = vectorizer.get_feature_names()
# Out:
# Counter({('player', 'pick'): 2,
#          ('pick', 'item'): 2,
#          ('item', 'online'): 2,
#          ('online', 'video'): 2,
#          ('video', 'game'): 2,
#          ('game', 'owns'): 2,
#          ('owns', 'item'): 2,
#          ('item', 'player'): 2,
#          ('player', 'company'): 2,
#          ('company', 'made'): 2,
#          ('made', 'game'): 2,
#          ('game', 'case'): 2,
#          ('case', 'answer'): 2,
#          ('answer', 'probably'): 2,
#          ('probably', 'closer'): 2,
#          ('closer', 'latter'): 2,
#          ('latter', 'item'): 2,
#          ('item', 'may'): 2,
#          ('may', 'player'): 2,
#          ('player', 'digital'): 2,
#          ('digital', 'inventory'): 2,
#          ('inventory', 'company'): 2,
#          ('company', 'take'): 2,
#          ('take', 'char'): 2,
#          ('char', 'youve'): 1,
#          ('youve', 'following'): 1,
#          ('following', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'news'): 1,
# ...

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin
#print(dict(bigram_counts_bc.most_common(10)))
token_count(bigram_counts_bc,N=10)
# Out:
# [(('satoshi', 'nakaboto'), 28),
#  (('bitcoin', 'btc'), 16),
#  (('btc', 'every'), 15),
#  (('char', 'robot'), 14),
#  (('robot', 'colleague'), 14),
#  (('colleague', 'satoshi'), 14),
#  (('nakaboto', 'writes'), 14),
#  (('writes', 'bitcoin'), 14),
#  (('every', 'fucking'), 14),
#  (('fucking', 'day'), 14)]

# %%
# Get the top 10 words for Ethereum
#print(dict(bigram_counts_eth.most_common(10)))
token_count(bigram_counts_eth,N=10)
# Out:
# [(('morning', 'intraday'), 13),
#  (('char', 'eos'), 12),
#  (('eos', 'eos'), 12),
#  (('eos', 'ended'), 12),
#  (('start', 'day'), 11),
#  (('early', 'morning'), 11),
#  (('ended', 'day'), 10),
#  (('day', 'saw'), 10),
#  (('saw', 'eos'), 10),
#  (('investing', 'com'), 8)]

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
wc_bc = WordCloud().generate(bc_joined)
plt.imshow(wc_bc)

# %%
# Generate the Ethereum word cloud
wc_eth = WordCloud().generate(eth_joined)
plt.imshow(wc_eth)

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Optional - download a language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
bc_articles = ' '.join(bcoin_df['text'])
bc_articles
# Out:
# 'Just when you thought the catastrophic Equifax breach was entirely in the rearview, the Department of Justice this week charged four Chinese military hackers with the theft. That\'s 147.9 million people\'s Social Security numbers and other personal information … [+4002 chars] After launching two cryptocurrency-oriented smartphones, the HTC Exodus 1 and the Exodus 1s, the company is expanding the lineup with an entirely new device: a 5G router that can function as a full Bitcoin node.\xa0\r\nCalled the HTC Exodus 5G hub, the Android-bas… [+2230 chars] If youve been following cryptocurrency news for the past few months, theres one word that keeps coming back DeFi, also known as decentralized finance. As the name suggests, DeFi aims to bridge the gap between decentralized blockchains and financial services.\r… [+983 chars] Indias Supreme Court on Wednesday overturned\xa0central banks two-year-old ban on cryptocurrency trading in the country in what many said was a historic verdict.\r\n
# ...

# %%
# Run the NER processor on all of the text
bc_NER = nlp(bc_articles)
# Add a title to the document
bc_NER.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(bc_NER, style='ent')
# Out:
# <h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Just when you thought the catastrophic
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Equifax
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  breach was entirely in the rearview,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Department of Justice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# ...

# %%
# List all Entities
list([ent.text for ent in bc_NER.ents])
# Out:
# ['Equifax',
#  'the Department of Justice',
#  'this week',
#  'four',
#  'Chinese',
#  '147.9 million',
#  'Social Security',
#  'two',
#  'HTC Exodus 1',
#  'Exodus',
#  '5',
#  'Bitcoin',
#  'HTC Exodus 5',
#  'Android-bas',
#  'the past few months',
#  'one',
#  'DeFi',
#  'DeFi',
#  'Indias Supreme Court',
#  'Wednesday',
#  'two-year-old',
#  'The Reserve Bank of India',
#  'April 2018',
#  'Wednesday',
#  'IRS',
#  'Dutch',
#  'two',
#  'Netherlands',
#  'Four',
#  'Bitcoin Halving',
#  'May 20th 2020',
#  'third',
#  '50 percent',
#  'BTC',
#  'Satoshi Nakaboto',
#  'Bitcoin',
#  'Bitcoin',
#  'Today',
#  'Satoshi Nakaboto',
#  'Bitcoin',
#  'the past 24 hours',
#  'Machiavelli',
#  'Satoshi Nakaboto',
#  'Bitcoin',
#  'Bitcoin',
#  'Today',
#  'Satoshi Nakaboto',
#  'Bitcoin',
#  'the past 24 hours',
#  'Stephen Hawking',
#  'Satoshi Nakaboto',
#  'Bitcoin',
#  'Bitcoin',
#  'Today',
#  'Satoshi Nakaboto',
#  'Bitcoin',
#  'the past 24 hours',
#  'Rousseau',
#  'Success',
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the bitcoin text together
eth_articles = ' '.join(eth_df['text'])

# %%
# Run the NER processor on all of the text
eth_NER = nlp(eth_articles)
# Add a title to the document
eth_NER.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(eth_NER, style='ent')
# Out:
# <h2 style="margin: 0">Ethereum NER</h2>
#
# </br>In most cases, the answer is probably closer to the latter. The item may be in the players digital inventory – but the company can take i… [+2713 chars] If youve been following cryptocurrency news for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past few months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , theres
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  word that keeps coming back
# ...

# %%
# List all Entities
list([ent.text for ent in eth_NER.ents])
# Out:
# ['the past few months',
#  'one',
#  'DeFi',
#  'DeFi',
#  'the Securities and Exchange Commission',
#  'Steven Seagal',
#  'Thursday',
#  'SEC',
#  '2018',
#  'Skale Network',
#  'blockchain',
#  'Skale Network',
#  'the N.O.D.E. Foundation',
#  'first',
#  'The South Korean National Assembly',
#  'today',
#  'crypto',
#  'blockchain',
#  '+3338',
#  'this past week',
#  '2020',
#  'DApps &amp',
#  'DLT',
#  'Last June',
#  'Washington',
#  'DC',
#  'Brendan Blumer',
#  'Block.one',
#  'Steve Jobs',
#  'Voice',
#  'A year earlier',
#  'Blumers company',
#  '+3666',
#  'some US Dollars',
#  'today',
#  'many days',
#  'today',
#  'Bitcoin',
#  'Ethereum',
#  'US',
#  'Centre',
#  'Circle',
#  'Intel',
#  'Today',
#  'IPFS',
#  'Terminal',
#  'one',
#  'February',
#  '26',
#  '2020',
#  '7 min',
#  'IRS',
#  'Last month',
#  'LinkedIn',
#  'the new year',
#  'ten',
#  '2019',
#  'blockchain',
#  'Blockchain',
#  'the United States',
#  'United',
#  'Satoshi Nakaboto',
#  'Bitcoin',
# ...
